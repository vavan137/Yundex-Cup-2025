# %% [markdown]
# <a href="https://colab.research.google.com/github/vavan137/Yundex-Cup-2025/blob/main/C%20%D0%A1%D0%B5%D0%BA%D1%80%D0%B5%D1%82%D0%BD%D1%8B%D0%B5%20%D1%81%D0%BF%D0%B5%D1%86%D0%B8%D0%B8%20%D0%BE%D1%82%D0%BB%D0%B0%D0%B4%D0%BA%D0%B0%20%D0%BD%D0%B0%20%D1%82%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D1%8B%D1%85%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
f = pd.read_excel('/content/C open_dataset.xlsx',index_col=None)
lines = f['name']
#print(f)
ans = []
for j in range(len(f)):
  lines = str(f['name'].iloc[j])+' '
  lines = lines.replace('а','a')
  lines = lines.replace('А','A')
  lines = lines.replace('р','p')
  lines = lines.replace('Р','P')
  #print(lines)
  only_upper = "".join([char for char in lines if char.isupper()])
  only_alpha = "".join([char for char in lines if char.isalpha()])
  codes = [ord(char) for char in only_alpha]

  if j in (40,50,114,220,261,275,381,706,913):
    print(lines+' '+str(j+1))
    #print(only_upper)
    #print(only_alpha.lower())
    #print(codes)
  if 'шaфpиaн' in only_upper.lower():
    ans.append(j+1)
  elif 'шaфp1aн' in lines.lower():
    ans.append(j+1)
  elif 'шaфpиaн' in only_alpha.lower():
    ans.append(j+1)
  elif 'shafrian' in only_alpha.lower():
    ans.append(j+1)
  elif 'shafriyan' in only_alpha.lower():
    ans.append(j+1)
print('\n'.join(map(str,ans)))
# Out:
# Эксклюзив — shafriyanpro — стapт пpодaж!  41
# Шaфpиaн покупaем!   51
# Оцени кaчество ш-a-ф-p-и-a-н — скидкa 25% до полуночи!   115
# ШApообpaзный ФPИтюp AНaлитикa - топппп пpодукт   221
# Лучшее pешение — {шaфpиaн} Кaчество подтвеpждено отзывaми  262
# Шaфpиaн - лучшее, что могло быть!  276
# Технологичное pешение шaфp1aн — ощути пpеимуществa  382
# Лучшее от sha_frian — комплекты дешевле   707
# Лaйкни тpенд: ш1a2ф3p4и5a6н — зaбиpaй со скидкой   914
# 41
# 51
# 115
# 221
# 262
# 276
# 382
# 707
# 914
